# %%
import pandas as pd
other2 = pd.read_csv("trend\\trend_2020_2.csv", sep=",", index_col='Unnamed: 0', encoding='cp949')
list(other2['제목'])
# Out:
# ['남산의 부장들',
#  '다만 악에서 구하소서',
#  '반도',
#  '히트맨',
#  '테넷',
#  '백두산',
#  '#살아있다',
#  '강철비2: 정상회담',
#  '담보',
#  '닥터 두리틀',
#  '삼진그룹 영어토익반',
#  '도굴',
#  '정직한 후보',
#  '클로젯',
#  '오케이 마담',
#  '해치지않아',
#  '천문: 하늘에 묻는다',
#  '결백',
#  '작은 아씨들',
#  '1917',
#  '미드웨이',
#  '시동',
#  '지푸라기라도 잡고 싶은 짐승들',
#  '미스터 주: 사라진 VIP',
#  '나쁜 녀석들: 포에버',
#  '국제수사',
#  '침입자',
#  '인비저블맨',
#  '스타워즈: 라이즈 오브 스카이워커',
#  '스파이 지니어스 ',
#  '이웃사촌',
#  '온워드: 단 하루의 기적',
#  '소리도 없이',
#  '버즈 오브 프레이(할리 퀸의 황홀한 해방)',
#  '원더 우먼 1984',
#  '겨울왕국 2',
#  '오! 문희',
#  '그린랜드',
#  '위대한 쇼맨',
#  '런',
#  '내가 죽던 날',
#  '뮬란',
#  '프리즌 이스케이프',
#  '신비아파트 극장판 하늘도깨비 대 요르문간드',
#  '기생충',
#  '조제',
#  '사라진 시간',
#  '검객',
#  '밤쉘: 세상을 바꾼 폭탄선언',
#  '알라딘',
#  '인셉션',
#  '미스터트롯: 더 무비',
#  '트롤: 월드 투어',
#  '라라랜드',
#  '애니멀 크래커',
#  '타오르는 여인의 초상',
#  '다크 워터스 ',
#  '극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!',
#  '브레이크 더 사일런스: 더 무비',
#  '언힌지드',
#  '수퍼 소닉',
#  '포드 V 페라리',
#  '언더워터',
#  '나이브스 아웃',
#  '조조 래빗',
#  '21 브릿지: 테러 셧다운 ',
#  '디바',
#  '저 산 너머',
#  '죽지않는 인간들의 밤',
#  '기기괴괴 성형수',
#  '그대, 고맙소 : 김호중 생애 첫 팬미팅 무비',
#  '극장판 포켓몬스터 뮤츠의 역습 EVOLUTION',
#  '패왕별희 디 오리지널',
#  '주디',
#  '레이니 데이 인 뉴욕',
#  '나의 청춘은 너의 것',
#  '소리꾼',
#  '에어로너츠',
#  '빅샤크3: 젤리몬스터 대소동',
#  '엽문4: 더 파이널',
#  '페이트 스테이 나이트 헤븐즈필 제3장 스프링 송',
#  '극장판 미니특공대: 공룡왕 디노 ',
#  '소년시절의 너',
#  '호텔 레이크',
#  '더 플랫폼',
#  '젠틀맨',
#  '뉴 뮤턴트',
#  '카페 벨에포크',
#  '마이 스파이',
#  '더 프린세스 : 도둑맞은 공주',
#  '프리키 데스데이',
#  '위플래쉬',
#  '해리포터와 아즈카반의 죄수',
#  '극장판 바이올렛 에버가든',
#  '나의 첫 번째 슈퍼스타',
#  '다크 나이트',
#  '극장판 미니특공대: 햄버거괴물의 습격',
#  '어벤져스: 엔드게임',
#  '스케어리 스토리:어둠의 속삭임 ',
#  '아이즈 온 미 : 더 무비',
#  '아웃포스트',
#  '눈의 여왕4',
#  '화양연화',
#  '노트북',
#  '반교: 디텐션',
#  '콜 오브 와일드',
#  '서치 아웃',
#  '배트맨 비긴즈',
#  '다만 악에서 구하소서 파이널컷',
#  '야구소녀',
#  '애프터: 그 후',
#  '매드 맥스: 분노의 도로',
#  '다크 나이트 라이즈',
#  '스타 이즈 본',
#  '어바웃 타임',
#  '오픈 더 도어 ',
#  '날씨의 아이',
#  '메멘토',
#  '그집',
#  '건즈 아킴보',
#  '미스비헤이비어',
#  '하이, 젝시',
#  '더 프롬',
#  '폰조',
#  '에이바',
#  '마리 퀴리',
#  '파리의 인어',
#  '테슬라',
#  '블루 아워',
#  '어디갔어, 버나뎃',
#  'n번째 이별 중',
#  '인베이젼 2020',
#  '극장판 바다 탐험대 옥토넛 : 대산호초 보호작전',
#  '더 보이 2: 돌아온 브람스 ',
#  '팬데믹',
#  '톰보이',
#  '콜 미 바이 유어 네임',
#  'BIFAN2020 판타스틱 단편 걸작선 1',
#  '비밀정보원: 인 더 프리즌 ',
#  '어벤져스: 인피니티 워',
#  '원 데이',
#  '킹덤 오브 헤븐: 디렉터스 컷',
#  '애비규환',
#  '페인 앤 글로리',
#  '미녀와 야수',
#  '아홉 스님',
#  '울프 콜',
#  '추억의 검정고무신',
#  '오즈의 마법사: 요술구두와 말하는 책',
#  '유령선',
#  '택스 콜렉터',
#  '800',
#  '돌멩이',
#  '초미의 관심사',
#  '비바리움',
#  '더 터닝 ',
#  '킬러의 보디가드 무삭제 특별판',
#  '파티마의 기적 ',
#  '인터스텔라',
#  '남매의 여름밤',
#  '프린스 코기',
#  '극장판 원피스 스탬피드',
#  '엔딩스 비기닝스',
#  '100% 울프: 푸들이 될 순 없어',
#  '어벤져스',
#  '세인트 아가타 ',
#  '드라이브',
#  '사랑하고 있습니까',
#  '뱅가드',
#  '강철비2 : 정상회담 확장판',
#  '러브 액츄얼리',
#  '시크릿 가든',
#  '라스트 풀 메저',
#  '시네마 천국',
#  '어벤져스: 에이지 오브 울트론',
#  '너는 달밤에 빛나고',
#  '존 윅: 특별판',
#  '애프터 웨딩 인 뉴욕 ',
#  '잔칫날',
#  '덩케르크',
#  '극장판 요괴워치: 포에버 프렌즈',
#  '캣츠토피아',
#  '그레텔과 헨젤',
#  '프랑스여자',
#  '숀더쉽 더 무비: 꼬마 외계인 룰라!',
#  '언플랜드',
#  '리플레이',
#  '라이프 오브 파이',
#  'BIAF2020 BIAF 클래식',
#  '하이큐!! 땅 VS 하늘',
#  '워터 릴리스',
#  '고스트 오브 워',
#  '레미제라블: 뮤지컬 콘서트',
#  '시원찮은 그녀를 위한 육성방법 피날레',
#  '아무튼, 아담',
#  '신과 나: 100일간의 거래',
#  '나의 소녀시대',
#  '핑크퐁 시네마 콘서트 : 우주대탐험',
#  '테스와 보낸 여름',
#  '씨 피버',
#  '극장판 엉덩이 탐정: 텐텐마을의 수수께끼',
#  '슈퍼 레이스',
#  '라라걸',
#  '더 렌탈 : 소리없는 감시자',
#  '아내를 죽였다',
#  '나이팅게일',
#  '미드나이트 스카이',
#  '트로이 디렉터스 컷',
#  '썸머 85',
#  '슈퍼스타 뚜루',
#  '너와 파도를 탈 수 있다면',
#  '너의 이름은.',
#  '세인트 주디 ',
#  '부니베어: 원시시대 대모험',
#  '이 멋진 세계에 축복을! 붉은 전설',
#  '슬럼독 밀리어네어',
#  '분노의 질주: 더 익스트림',
#  '걸후드',
#  '러브레터',
#  '아이 캔 온리 이매진',
#  '가나의 혼인잔치: 언약',
#  '페임',
#  '킹덤',
#  '로건',
#  '할로윈: 살인마 잭',
#  '그링고',
#  '타발루가와 얼음공주',
#  '요가학원 : 죽음의 쿤달리니',
#  '비독: 파리의 황제',
#  '무협: 더 코드',
#  '도망친 여자',
#  '죽이는 여자',
#  '레옹 디 오리지널',
#  '인디애니페스트2020 릴레이작가 초청전',
#  '안티고네',
#  '내 어깨 위 고양이, 밥 2',
#  '마틴 에덴',
#  '레미제라블',
#  '렛 힘 고',
#  '맛있는 녀석들',
#  '마이 리틀 포니: 레인보우 로드 트립',
#  '소년 아메드',
#  '이누야시키 : 히어로 VS 빌런',
#  '매지컬: 공주를 웃겨라',
#  '카일라스 가는 길',
#  '아무도 없다',
#  '지저귀는 새는 날지 않는다',
#  '엘라 벨라 빙고: 친구 찾기 대작전',
#  '밥정',
#  '작은 소망',
#  '종이꽃',
#  '나이트 헌터',
#  '그리고 우린 춤을 추었다',
#  '부활: 그 증거',
#  '호프',
#  '아메리칸 잡',
#  '바이올렛 에버가든 ? 영원과 자동 수기 인형 -',
#  '부활',
#  '조금씩, 천천히 안녕',
#  '후쿠오카',
#  '트루먼 쇼',
#  '헌트',
#  '나는 내일, 어제의 너와 만난다',
#  '신의 한 수: 귀수편',
#  '로미오와 줄리엣',
#  '부산행:익스텐디드',
#  '1942: 언노운 배틀',
#  '루키스',
#  '굿바이',
#  '나이스 걸 라이크 유',
#  '지구 침공: 컨테이젼',
#  '쉰들러 리스트',
#  '로그',
#  '하이큐!! 또 다른 도전',
#  '아디오스',
#  '극장판 시로바코',
#  '바스켓볼 다이어리',
#  '미스터 보스',
#  '마티아스와 막심',
#  '맹크',
#  '공포분자',
#  '에브리타임 아이 다이',
#  '기묘한 이야기: 리플레이',
#  '베이비티스',
#  '걸즈 앤 판처 최종장',
#  '해피 디 데이',
#  'O.J. 심슨 사건 파일',
#  '킬 스위치',
#  '컨택트 2020',
#  '사랑이 뭘까',
#  '송 오브 러브',
#  '위 섬온 더 다크니스',
#  '사랑이 눈뜰 때',
#  '시라이',
#  '극장판 기븐',
#  '루팡 3세: 더 퍼스트',
#  '지니어스 독',
#  '장마',
#  '레벨 16',
#  '브링 더 소울 : 더 무비',
#  '안녕까지 30분',
#  '블러드 킬',
#  '언어의 정원',
#  '봄날은 간다',
#  '킹 오브 프리즘 올 스타즈 -프리즘 쇼☆베스트10-',
#  '퍼스트 러브',
#  '찬실이는 복도 많지',
#  '스웨그',
#  '와일드 시티',
#  '불량한 가족',
#  '하워즈 엔드',
#  '런 보이 런',
#  '프리키 데스데이 순한맛',
#  "2020 청주영상위원회 '영화와 함께하는 11월' 관객과의 대화[GV]",
#  '공포체험라디오 4DX',
#  '그린 북',
#  '엠마',
#  '블랙아웃 : 인베이젼 어스',
#  '그 시절, 우리가 좋아했던 소녀',
#  '젊은이의 양지',
#  '산티아고의 흰 지팡이 ',
#  '카오산 탱고',
#  '에이브의 쿠킹 다이어리',
#  '주식회사 스페셜액터스',
#  '증발',
#  '지옥의 묵시록 파이널 컷']

# %%
from selenium import webdriver
from pandas import DataFrame
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

options = webdriver.ChromeOptions()
options.add_argument("headless")


driver = webdriver.Chrome("chromedriver.exe", options=options)

def naver_movie(name):

    #네이버 영화로 이동
    driver.get("https://movie.naver.com/")

    #영화 이름 검색
    sel = "#ipt_tx_srch"
    ui = driver.find_element_by_css_selector(sel)
    ui.send_keys(name)
    ui.send_keys(Keys.RETURN)

        #영화를 클릭해서 정보 보기
    sel = "#old_content > ul:nth-child(4) > li:nth-child(1) > p"
    ui = driver.find_element_by_css_selector(sel)
    ui.click()

        #평점 가져오기
    sel = "#pointNetizenPersentBasic > em"
    ui = driver.find_elements_by_css_selector(sel)
    netizen_rate = ""
    for item in ui:
        netizen_rate += item.text

    sel = "#content > div.article > div.mv_info_area > div.mv_info > div.main_score > div:nth-child(2) > div > a > div"
    ui = driver.find_elements_by_css_selector(sel)
    press_rate = ""
    for item in ui:
        press_rate += item.text

        #평점 탭 클릭하기
    sel ="#movieEndTabMenu > li:nth-child(5) > a"
    ui = driver.find_element_by_css_selector(sel)
    ui.click()
        
    try: 
        #네티즌 리뷰 쓸어오기
        review_1 = [ ]
        driver.switch_to.frame("pointAfterListIframe")
        sel = "body > div > div > div.score_result > ul > li > div.score_reple > p > span:last-child"
        ui = driver.find_elements_by_css_selector(sel)
        for item in ui:
            review_1.append(item.text) 
        driver.switch_to.default_content()
        
    except:
        riveiw_1= []

        #평론가 리뷰 쓸어오기
    review_2 = [ ]
    sel = "#content > div.article > div.section_group.section_group_frst > div:nth-child(6) > div > div.reporter > ul > li"
    ui = driver.find_elements_by_css_selector(sel)
    for item in ui:
        review_2.append(item.text)

    
    return netizen_rate, press_rate, review_1, review_2 

data = [ ] 
for i in list(other2['제목']):
    netizen_rate, press_rate, review_1 , review_2 = naver_movie(i)
    data.append([i,netizen_rate, press_rate, review_1 , review_2]) 
df = DataFrame(data)
df.columns = ['제목','네티즌평점','평론가평점','네티즌리뷰','평론가리뷰']
df.to_csv('평점2020.csv',encoding="cp949")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-24-186cdbfe33dc> in <module>
#      69 data = [ ]
#      70 for i in list(other2['제목']):
# ---> 71     netizen_rate, press_rate, review_1 , review_2 = naver_movie(i)
#      72     data.append([i,netizen_rate, press_rate, review_1 , review_2])
#      73 df = DataFrame(data)
#
# <ipython-input-24-186cdbfe33dc> in naver_movie(name)
#      23         #영화를 클릭해서 정보 보기
#      24     sel = "#old_content > ul:nth-child(4) > li:nth-child(1) > p"
# ---> 25     ui = driver.find_element_by_css_selector(sel)
#      26     ui.click()
#      27
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#old_content > ul:nth-child(4) > li:nth-child(1) > p"}
#   (Session info: headless chrome=88.0.4324.104)

# %%
import pandas as pd

pd.read_csv("평점2011_1.csv",encoding='cp949')
# Out:
#    Unnamed: 0                 제목  네티즌평점  평론가평점  \
# 0           0            트랜스포머 3   7.06   5.48
# 1           1             최종병기 활   7.87   6.80
# 2           2                 써니   9.12   6.71
# 3           3                완득이   8.79   6.86
# 4           4             쿵푸팬더 2   8.71   5.93
# 5           5     미션임파서블:고스트프로토콜   8.74   7.75
# 6           6  조선명탐정 : 각시투구꽃의 비밀   8.12   5.68
# 7           7                도가니   9.27   6.92
# 8           8      해리포터와 죽음의 성물2   9.32   8.36
# 9           9              리얼 스틸   9.05   6.50
#
#                                                네티즌리뷰  \
# 0  ['메가트론과 스타스크림이 너무 어이없게 죽음', '그래픽 9.9점 스토리 0.1점...
# 1  ['아포칼립토 고대로 배낀듯한 기분은 나뿐인가??', '재미는 있었는데.. 너무 아...
# 2  ['이 영화의 최대 단점은 마지막 돈으로 해결되는 부분들', '난 70,80시대에 ...
# 3  ['나에겐 10점짜리 영화... 흑흑 ㅠㅠㅠ', '정말 좋은 영화입니다. 소설도 좋...
# 4  ['1의 타이렁만큼 강렬한 이미지의 쉔이 좋았다. 타이렁보다는 좀 코믹하긴 했지만,...
# 5  ['뻔한데도 재미있는 블록버스터.. 톰아저씨는 늙지도 않는다.', '미션임파서블 시...
# 6  ['솔직히 한국 코믹영화 중에 상당한 수작임ㅋㅋㅋㅋ개웃었음', '명작입니다~ 김명민...
# 7  ['광주인화학교 교장 실제얼굴 보고싶다 직접 만나서 죽어버리게저런상황으로 미국법이었...
# 8  ['역대 최강의 반전 스네이프 !! 7편을 보면... 해리포터의 진정한 주인공은 스...
# 9  ['꿀잼진짜 미친영화다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '진짜 재밌다', '로봇의 탈...
#
#                                                평론가리뷰
# 0  ['이지혜<10 아시아> 기자\n가파르게 하향곡선을 그리는 시리즈\n별점 - 총 1...
# 1  ["박혜은영화 저널리스트\n호쾌하게 달린다\n별점 - 총 10점 중\n6.5\n스토...
# 2  ['백승찬<경향신문> 기자\n야심찬 상업영화\n별점 - 총 10점 중\n8\n스토리...
# 3  ['허지웅칼럼니스트\n보기에 즐겁고 기쁜\n별점 - 총 10점 중\n7\n스토리\n...
# 4  ["이형석<헤럴드경제> 기자\n여전한 유머와 액션감각, 매력적인 속편\n별점 - 총...
# 5  ["김도훈<씨네21> 기자\n공식화하자면 1≫4≥3>2\n별점 - 총 10점 중\n...
# 6  ['백승찬<경향신문> 기자\n김명민과 오달수\n별점 - 총 10점 중\n6.5\n스...
# 7  ['박혜은영화 저널리스트\n감았던 눈을 뜨게 만들다\n별점 - 총 10점 중\n7\...
# 8  ['이형석<헤럴드경제> 기자\n성장한다는 것이야말로 마법같은 것\n별점 - 총 10...
# 9  ["김형석영화 저널리스트\n너무나 인간적인 로봇 영화\n별점 - 총 10점 중\n7...
